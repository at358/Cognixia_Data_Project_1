# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display
print('Libraries Imported')
# Out:
# Libraries Imported

# %%
#Point 1 Retrieve Table from csv file
data = pd.read_csv(r"E:\Cognixia\FIFA_2020_Data_Analysis-main\FIFA_2020_Data_Analysis-main\players_20.csv")
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
#Point 2 Display all columns
list(data.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
#Point 3 Display Shape of Table
data.shape
# Out:
# (18278, 104)

# %%
#Point 4 Return Count of Players per Nation
counts_Nationality = data["nationality"].value_counts()
counts_Nationality = counts_Nationality.reset_index()
counts_Nationality.columns= ["Nations","Counts"]
counts_Nationality
# Out:
#             Nations  Counts
# 0           England    1667
# 1           Germany    1216
# 2             Spain    1035
# 3            France     984
# 4         Argentina     886
# ..              ...     ...
# 157       Indonesia       1
# 158         Bahrain       1
# 159  Chinese Taipei       1
# 160            Chad       1
# 161          Belize       1
#
# [162 rows x 2 columns]

# %%
#Additional Visual of All Nation Player Count
counts_Nationality = data["nationality"].value_counts()
counts_Nationality = counts_Nationality.reset_index()
counts_Nationality.columns= ["Nations","Counts"]
sns.catplot(y="Nations",x="Counts",data=counts_Nationality.head(50),height=20,kind="bar")
plt.title("Nation Wise Players Counts",fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.grid()
plt.show()
plt.savefig('Player_Count_By_Nation.png')

# %%
#Point 5 Display Top Ten Countries with the Most Players
counts_Nationality = data["nationality"].value_counts()
counts_Nationality = counts_Nationality.reset_index()
counts_Nationality.columns= ["Nations","Counts"]
counts_Nationality.head(10)
# Out:
#        Nations  Counts
# 0      England    1667
# 1      Germany    1216
# 2        Spain    1035
# 3       France     984
# 4    Argentina     886
# 5       Brazil     824
# 6        Italy     732
# 7     Colombia     591
# 8        Japan     453
# 9  Netherlands     416

# %%
#Point 6 Create Graph using Point 5 table
plt.figure(figsize=(10, 7))
sns.barplot(
    x="Nations", 
    y="Counts", 
    data=counts_Nationality.head(5), 
    estimator=sum, 
    ci=None, 
    color='#69b3a2');
plt.title("Nation Wise Players Counts",fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.grid()
plt.show()
plt.savefig('Top_Ten_Nations_Player_Count.png')

# %%
#Point 7 Return Top 5 Highest Wages among Players
Gen = data.sort_values(by = 'wage_eur' , ascending = False)[['short_name','wage_eur']].head(5)
Gen.nlargest(5, ['wage_eur'])
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
#Point 8 Return Top 5 players with the Highest Salaries
Gen = data.sort_values(by = 'wage_eur' , ascending = False)[['short_name','club','value_eur', 'wage_eur']].head(5)
print("The top 5 players with the highest salaries are: ")
Gen.nlargest(5, ['wage_eur'])
# Out:
# The top 5 players with the highest salaries are:
#            short_name             club  value_eur  wage_eur
# 0            L. Messi     FC Barcelona   95500000    565000
# 4           E. Hazard      Real Madrid   90000000    470000
# 1   Cristiano Ronaldo         Juventus   58500000    405000
# 5        K. De Bruyne  Manchester City   90000000    370000
# 22       A. Griezmann     FC Barcelona   69000000    370000

# %%
#Point 9 Graph of Point 8
plt.figure(figsize=(12, 7))
sns.barplot(
    x="short_name", 
    y="wage_eur", 
    data=Gen.head(5), 
    estimator=sum, 
    ci=None, 
    color='#69b3a2');
plt.title("Highest Paid Players",fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.grid()
plt.show()
plt.savefig('HighestPaidPlayer.png')

# %%
#Function to extract specific club players
def Club(x):
    return data[data['club'] == x ][
        ['short_name','age','club',"player_positions","overall",'wage_eur',"value_eur","height_cm", "weight_kg","shooting","defending", "nationality"]].sort_values(by=["overall"],ascending=False)

#Function to extract specific country players
def Country(x):
    return data[data['nationality'] == x ][['short_name','age','nationality',"player_positions",
                                            "overall","wage_eur","value_eur","height_cm", "weight_kg","shooting","defending"]].sort_values(by=["overall"],ascending=False)

# %%
Chelsea = Club("Chelsea")
PSG = Club("Paris Saint-Germain")
Juventus = Club("Juventus")
BVB = Club("Borussia Dortmund")
Real_Madrid = Club("Real Madrid")
Germany = Country("Germany")
England = Country("England")
France = Country("France")

# %%
#Point 10 Return Top 10 Overall Players Playing for Germany
German = Germany[['short_name', 'overall']]
German.nlargest(10, ['overall'])
# Out:
#         short_name  overall
# 6    M. ter Stegen       90
# 36        T. Kroos       88
# 37         M. Reus       88
# 31        M. Neuer       88
# 49      M. Hummels       87
# 55         L. Sané       86
# 61      J. Kimmich       86
# 70       T. Müller       86
# 77         N. Süle       85
# 122        B. Leno       84

# %%
#Point 11 Return top 5 tallest players Playing for Germany
German = Germany[["short_name", "wage_eur","height_cm", "weight_kg"]]
German.nlargest(5, ['height_cm'])
# Out:
#          short_name  wage_eur  height_cm  weight_kg
# 8016      A. Seydel      9000        199         90
# 1217       M. Esser     23000        198         97
# 1389  L. Unnerstall     14000        198        103
# 518     R. Fährmann     43000        197         98
# 4449     T. Kessler     12000        197         92

# %%
#Point 12 Return top 5 highest wages among players Playing for Germany
German = Germany[["short_name", "wage_eur"]]
German.nlargest(5, ['wage_eur'])
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 37         M. Reus    170000

# %%
#Point 13 Return top 5 highest shooting score players 
Shooters = data[["short_name", "shooting"]].groupby("shooting").head(5)
Shooters.nlargest(5, ['shooting'])
# Out:
#            short_name  shooting
# 1   Cristiano Ronaldo      93.0
# 0            L. Messi      92.0
# 12            H. Kane      91.0
# 17          S. Agüero      90.0
# 19          L. Suárez      89.0

# %%
#Point 14 Top 5 defending score players
Defending = data[["short_name", "defending", "nationality","club"]].groupby("defending").head(5)
Defending.nlargest(5, ['defending'])
# Out:
#       short_name  defending  nationality               club
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 16  G. Chiellini       90.0        Italy           Juventus
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
#Point 12 Return top 5 highest wages among players who are part of Real Madrid
RealMadrid_Wages = Real_Madrid[["short_name", "wage_eur"]].groupby("wage_eur").head(5)
RealMadrid_Wages.nlargest(5, ['wage_eur'])
# Out:
#       short_name  wage_eur
# 4      E. Hazard    470000
# 8      L. Modrić    340000
# 36      T. Kroos    330000
# 18  Sergio Ramos    300000
# 46    K. Benzema    285000

# %%
#Point 16 Return top 5 highest shooting score players who are part of Real Madrid
RealMadrid_Wages = Real_Madrid[["short_name", "shooting"]].groupby("shooting").head(5)
RealMadrid_Wages.nlargest(5, ['shooting'])
# Out:
#        short_name  shooting
# 100       G. Bale      87.0
# 106  J. Rodríguez      86.0
# 4       E. Hazard      83.0
# 46     K. Benzema      82.0
# 161      L. Jović      82.0

# %%
#Point 17 Return top 5 highest defending score players who are part of Real Madrid
RealMadrid_Wages = Real_Madrid[["short_name", "defending"]].groupby("defending").head(5)
RealMadrid_Wages.nlargest(5, ['defending'])
# Out:
#           short_name  defending
# 18      Sergio Ramos       87.0
# 42          Casemiro       85.0
# 76         R. Varane       85.0
# 94          Carvajal       82.0
# 277  Nacho Fernández       81.0

# %%
#Point 18 Return top 5 highest overall score players who are part of Real Madrid
RealMadrid_Wages = Real_Madrid[["short_name", "nationality","overall"]].groupby("overall").head(5)
RealMadrid_Wages.nlargest(5, ['overall'])
# Out:
#       short_name nationality  overall
# 4      E. Hazard     Belgium       91
# 8      L. Modrić     Croatia       90
# 18  Sergio Ramos       Spain       89
# 28   T. Courtois     Belgium       88
# 36      T. Kroos     Germany       88
